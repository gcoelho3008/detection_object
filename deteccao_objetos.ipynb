# %% [markdown]
# <a href="https://colab.research.google.com/github/gcoelho3008/detection_object/blob/main/deteccao_objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### carros
#
# ---

# %%
import cv2

from google.colab.patches import cv2_imshow

# %%
detector_carros = cv2.CascadeClassifier('/content/drive/MyDrive/Visão Computacional Guia Completo/Visão Computacional Guia Completo/Cascades/cars.xml')

# %%
imagem = cv2.imread('/content/drive/MyDrive/Visão Computacional Guia Completo/Visão Computacional Guia Completo/Images/car.jpg')
imagem.shape
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
deteccoes = detector_carros.detectMultiScale(imagem_cinza, scaleFactor = 1.03, minNeighbors = 3)
for (x, y, w, h) in deteccoes:
  cv2.rectangle(imagem, (x, y), (x + w, y + h), (0, 255, 0), 2)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=468x286>

# %% [markdown]
# ### Relogio

# %%
detector_relogios = cv2.CascadeClassifier('/content/drive/MyDrive/Visão Computacional Guia Completo/Visão Computacional Guia Completo/Cascades/clocks.xml')

# %%
imagem = cv2.imread('/content/drive/MyDrive/Visão Computacional Guia Completo/Visão Computacional Guia Completo/Images/clock.jpg')
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
deteccoes = detector_relogios.detectMultiScale(imagem_cinza, scaleFactor= 1.03, minNeighbors= 1,
                                               minSize=(32 ,32))
for (x, y, w, h) in deteccoes:
  cv2.rectangle(imagem, (x, y), (x + w, y + h), (0, 255, 0), 2)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=450x438>

# %% [markdown]
# ### Corpo Inteiro

# %%
detector_corpo = cv2.CascadeClassifier('/content/drive/MyDrive/Visão Computacional Guia Completo/Visão Computacional Guia Completo/Cascades/fullbody.xml')

# %%
imagem = cv2.imread('/content/drive/MyDrive/Visão Computacional Guia Completo/Visão Computacional Guia Completo/Images/people3.jpg')
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
deteccoes = detector_corpo.detectMultiScale(imagem_cinza, scaleFactor= 1.03, minNeighbors= 5,
                                            minSize= (50, 50))
for (x, y, w, h) in deteccoes:
  cv2.rectangle(imagem, (x, y), (x + w, y + h), (0, 255, 0), 2)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=626x294>
